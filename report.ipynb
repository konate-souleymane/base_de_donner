# %%
import pyodbc
import pandas as pd

# %%
connection = pyodbc.connect('Driver={SQL Server};'
                            'Server=konate\SQLEXPRESS;'
                            'Database=ODS;'
                            'Trusted_Connection=yes;')

# %%
cursor = connection.cursor()

create_table_query = """
SELECT * FROM BNLC ;
"""
result = cursor.execute(create_table_query).fetchall()

pd.DataFrame.from_records(result)
# Out:
#                0     1                                            2   \
# 0     2A004-C-001  None                                    A Confina
# 1     01024-C-001  None                            Mairie d'Attignat
# 2     01049-C-001  None                 Aire de covoiturage Montluel
# 3     01089-C-001  None        Aire de covoiturage Ch+óteau-Gaillard
# 4     01093-C-001  None                              Parking Bel Air
# ...           ...   ...                                          ...
# 8659  66175-C-001  None           Aire de Saint-G+®nis-des-Fontaines
# 8660  49018-C-006  None  Parking de la mairie - Saint Martin d'Arc+®
# 8661  33000-C-001     1                                  Villandraut
# 8662  66069-C-001  None       Aire de covoiturage d'Espira de l'Agly
# 8663  66008-C-003  None      Aire de covoiturage Christian Bourquin
#
#                                                      3   \
# 0          Lieu-dit Stagnacciu (Croisement RT22 - RD31)
# 1             Place De La Fontaine- Anciens Combattants
# 2                                             La Boisse
# 3                                     Ch+óteau-Gaillard
# 4                   Route De Neuville - Parking Bel Air
# ...                                                 ...
# 8659                      D618 - Echangeur de St-G+®nis
# 8660                                    8 VC Grande rue
# 8661                                      3 villandraut
# 8662                  RD117  - direction Cases-de-P+¿ne
# 8663  Sortie n-¦10 de la 2x2 voies (RD914) ÔÇô direc...
#
#                              4      5                    6           7     8   \
# 0                       AJACCIO  2A004         Supermarch+®  2019-08-28  true
# 1                      ATTIGNAT  01024              Parking  2019-08-29  true
# 2                     LA BOISSE  01049  Aire de covoiturage  2019-08-29  true
# 3              CHATEAU GAILLARD  01089   Sortie d'autoroute  2019-08-29  true
# 4      CHATILLON SUR CHALARONNE  01093              Parking  2019-08-29  true
# ...                         ...    ...                  ...         ...   ...
# 8659  SAINT-GENIS-DES-FONTAINES  66175  Aire de covoiturage  2022-08-05  true
# 8660             BAUGE EN ANJOU  49018              Parking  2022-08-17  true
# 8661                villandraut  33000  Aire de covoiturage  2021-11-02  true
# 8662           ESPIRA-DE-L'AGLY  66069  Aire de covoiturage  2022-10-12  true
# 8663           ARGELES SUR MER   66008  Aire de covoiturage  2022-10-10  true
#
#              9                  10                  11   12    13    14    15  \
# 0     539830349           8.783403          41.9523692    0     0  None  24/7
# 1     200071751        5.158352778         46.28957222    5  None  None  None
# 2     240100610           5.048432           45.840543  100  None  None  None
# 3     240100883           5.311396           45.977088   15  None  None  None
# 4     200071751        4.964663889         46.12900556   10  None  None  None
# ...         ...                ...                 ...  ...   ...   ...   ...
# 8659  226600013   2.91886682866195    42.5488485334644    7     1  None  None
# 8660  244900882          -0.085044            47.55954   45     1  None  None
# 8661       None          -0.371283           44.457274   10     3  None  24/7
# 8662  226600013   2.82463737398696   42.77777420590214   13     1  None  24/7
# 8663  226600013  3.00629718122744   42.56353596223298    23     0  None  24/7
#
#                              16     17  \
# 0                         Prive   true
# 1                          None   None
# 2                          None   None
# 3                          None   None
# 4                          None   None
# ...                         ...    ...
# 8659  Conseil D+®partemental 66  false
# 8660                      Ville   true
# 8661                    Commune  false
# 8662  Conseil D+®partemental 66  false
# 8663  Conseil D+®partemental 66   None
#
#                                                  18
# 0                    transport : Bus Muvistrada (2)
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 8659                                           None
# 8660                                           None
# 8661                                           None
# 8662                                           None
# 8663  aire coll+®e +á l'aire multimodale du lyc+®e
#
# [8664 rows x 19 columns]
